# %% [raw]
# 特征名	含义	取值范围
# TV_ad	电视广告投放金额（万元）	10-100 万元
# Social_ad	社交媒体广告投放金额（万元）	5-50 万元
# Outdoor_ad	户外广告投放金额（万元）	3-30 万元
# Ad_days	广告投放天数（天）	7-30 天
# Sales	产品销售额（万元）	标签（待预测）

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 2. 手动构造真实逻辑的数据集（100个样本，含业务逻辑+随机噪声）
np.random.seed(42)  # 固定随机种子，结果可复现
n_samples = 100  # 100条广告投放记录

# 构造4个特征（符合业务常识的取值范围）
TV_ad = np.random.uniform(10, 100, n_samples)  # 电视广告：10-100万
Social_ad = np.random.uniform(5, 50, n_samples)  # 社交媒体：5-50万
Outdoor_ad = np.random.uniform(3, 30, n_samples)  # 户外广告：3-30万
Ad_days = np.random.randint(7, 31, n_samples)  # 投放天数：7-30天

# %%
# 业务逻辑：电视广告权重最高（0.8），其次是社交媒体（0.5）、投放天数（0.3）、户外广告（0.2）
Sales = (0.8 * TV_ad + 0.5 * Social_ad + 0.2 * Outdoor_ad + 0.3 * Ad_days 
         + np.random.randn(n_samples) * 2)  # 噪声：模拟不可控因素

# %%
# 转换为DataFrame（方便查看和处理）
data={'电视广告投放金额':TV_ad,'设计媒体广告投放金额':Social_ad,'户外广告投放金额':Outdoor_ad,'广告投放天数':Ad_days,'产品销售额':Sales}
df=pd.DataFrame(data)

# %%
# # 查看数据集基本信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   电视广告投放金额    100 non-null    float64
#  1   设计媒体广告投放金额  100 non-null    float64
#  2   户外广告投放金额    100 non-null    float64
#  3   广告投放天数      100 non-null    int32
#  4   产品销售额       100 non-null    float64
# dtypes: float64(4), int32(1)
# memory usage: 3.6 KB

# %%
# 查看数据统计描述
df.describe()
# Out:
#          电视广告投放金额  设计媒体广告投放金额    户外广告投放金额      广告投放天数       产品销售额
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    52.316267   27.402428   16.975236   18.470000   64.374224
# std     26.774047   13.190006    7.922509    7.425665   21.999484
# min     10.496991    5.312846    3.136663    7.000000   22.275827
# 25%     27.388068   15.890204   10.475756   11.000000   44.418629
# 50%     51.772821   27.753119   18.188983   19.000000   61.997424
# 75%     75.718281   39.478262   23.313907   25.000000   81.573866
# max     98.819824   49.354270   29.731454   30.000000  107.325215

# %%
df.head()
# Out:
#     电视广告投放金额  设计媒体广告投放金额   户外广告投放金额  广告投放天数       产品销售额
# 0  43.708611    6.414313  20.334854      19   48.161615
# 1  95.564288   33.638469   5.271779      26  101.264969
# 2  75.879455   19.146019   7.363975      21   80.509791
# 3  63.879264   27.885681  27.260963       9   70.615995
# 4  24.041678   45.840491  19.373585      29   57.838150

# %%
# 3. 数据预处理
# 3.1 分离特征（X）和标签（y）
x=df[['电视广告投放金额','设计媒体广告投放金额','户外广告投放金额','广告投放天数']]
x
# Out:
#      电视广告投放金额  设计媒体广告投放金额   户外广告投放金额  广告投放天数
# 0   43.708611    6.414313  20.334854      19
# 1   95.564288   33.638469   5.271779      26
# 2   75.879455   19.146019   7.363975      21
# 3   63.879264   27.885681  27.260963       9
# 4   24.041678   45.840491  19.373585      29
# ..        ...         ...        ...     ...
# 95  54.441604   20.714431  17.100568      18
# 96  57.045955   37.668006  23.789826      19
# 97  48.478692   45.369962   8.827168      18
# 98  12.287721   44.918889  19.818043      20
# 99  19.710228   40.094400   5.304382       8
#
# [100 rows x 4 columns]

# %%
y=df['产品销售额']
y
# Out:
# 0      48.161615
# 1     101.264969
# 2      80.509791
# 3      70.615995
# 4      57.838150
#          ...
# 95     62.260915
# 96     72.954273
# 97     67.651041
# 98     39.834985
# 99     42.454547
# Name: 产品销售额, Length: 100, dtype: float64

# %%
# 3.2 划分训练集（80%）和测试集（20%）
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 70 to 59
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   电视广告投放金额    80 non-null     float64
#  1   设计媒体广告投放金额  80 non-null     float64
#  2   户外广告投放金额    80 non-null     float64
#  3   广告投放天数      80 non-null     int32
# dtypes: float64(3), int32(1)
# memory usage: 2.8 KB

# %%
# 4. 训练多元线性回归模型
#标准化要训练的数据
from sklearn.preprocessing import StandardScaler
#实例化标准库
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
x_train_scaled
# Out:
# array([[ 1.03026256e+00,  5.55934352e-01,  1.03416007e+00,
#          7.47090239e-02],
#        [-1.19194578e+00, -1.24928750e+00,  9.88681663e-01,
#          1.56888950e+00],
#        [-3.43883999e-01, -1.34110914e+00, -4.46132388e-01,
#         -1.55530604e+00],
#        [-1.11196228e+00,  1.28641192e+00,  2.26208004e-01,
#          1.16138574e+00],
#        [ 8.08888613e-01,  4.47657924e-01,  3.52705417e-02,
#          4.82212791e-01],
#        [ 1.13166798e+00, -1.08550163e+00,  6.75932995e-01,
#         -1.55530604e+00],
#        [-1.38758267e+00, -3.37182303e-01, -1.33852120e+00,
#          1.02555115e+00],
#        [-1.49817069e+00,  1.25631101e+00,  4.09153741e-01,
#          2.10543613e-01],
#        [ 1.59651389e+00, -1.22463841e+00,  1.17418188e+00,
#          4.82212791e-01],
#        [ 1.63448433e+00,  4.18367616e-01, -1.39661262e+00,
#          1.02555115e+00],
#        [ 1.34827416e+00,  8.16623454e-01,  5.45273346e-01,
#          4.82212791e-01],
#        [-9.40603138e-02,  1.53942612e+00, -1.08499641e+00,
#          4.82212791e-01],
#        [ 1.15265978e+00, -6.28601880e-01,  7.42861190e-01,
#          1.29722032e+00],
#        [ 4.42573399e-01, -8.96664736e-03,  1.33311436e+00,
#         -1.28363687e+00],
#        [-1.10711967e+00, -6.36700882e-01,  6.57604382e-01,
#          8.89716558e-01],
#        [-9.20714596e-01,  8.36908761e-01,  6.54299726e-01,
#         -1.01196769e+00],
#        [ 4.50890154e-01, -9.44171965e-01, -1.66166495e+00,
#          7.47090239e-02],
#        [-8.65339312e-01,  9.92348478e-01, -9.26931658e-01,
#          1.56888950e+00],
#        [-1.28463113e+00,  5.37787266e-01,  1.45914278e+00,
#         -1.55530604e+00],
#        [ 1.04004028e+00, -9.08191688e-01, -3.87872218e-01,
#          4.82212791e-01],
#        [-1.21847326e-01,  1.27460438e+00,  4.98788121e-01,
#          1.43305491e+00],
#        [-1.46780415e+00, -4.68137085e-02,  1.38778237e+00,
#          1.29722032e+00],
#        [ 5.74268787e-01,  1.46905472e-01,  1.40188353e-01,
#         -1.01196769e+00],
#        [-7.08110321e-01, -7.56837330e-01, -1.62682322e+00,
#         -1.01196769e+00],
#        [-5.52936655e-01,  2.51958688e-02, -7.37546571e-01,
#          1.43305491e+00],
#        [-5.95151782e-01, -6.45982285e-01, -1.36465417e+00,
#         -1.55530604e+00],
#        [ 8.93990418e-01, -6.58174890e-01, -1.13688836e+00,
#          3.46378202e-01],
#        [-1.25355288e+00,  6.41022316e-01, -1.59712874e+00,
#         -1.28363687e+00],
#        [ 1.69837120e+00,  1.32710833e+00, -6.91706026e-01,
#         -6.11255650e-02],
#        [ 4.72658852e-01, -3.13689296e-01,  9.85392353e-01,
#          1.16138574e+00],
#        [ 1.17657575e+00, -9.51868245e-01,  1.38233964e+00,
#          1.56888950e+00],
#        [ 1.85521499e-01,  7.17693685e-01,  9.02209028e-01,
#          7.47090239e-02],
#        [-1.36757393e-01,  1.28981803e+00, -9.55248333e-01,
#         -6.11255650e-02],
#        [-4.63949370e-01,  1.38202188e+00, -4.19763534e-01,
#         -1.28363687e+00],
#        [ 4.40005423e-01,  1.58578441e+00, -1.11052995e+00,
#         -7.40298510e-01],
#        [ 1.76499594e-01, -2.86609300e-02,  1.56137183e+00,
#          2.10543613e-01],
#        [ 4.87244048e-01,  9.90074668e-01,  5.25535202e-01,
#         -6.11255650e-02],
#        [-3.16195845e-01, -1.60392409e+00,  4.73310490e-01,
#          7.47090239e-02],
#        [ 1.41949511e+00,  6.14978221e-02, -7.18210595e-01,
#         -6.11255650e-02],
#        [ 8.75523637e-02, -5.41668575e-01,  7.18076920e-02,
#         -6.11255650e-02],
#        [ 1.62829290e+00, -5.80425588e-01, -2.78254894e-02,
#         -7.40298510e-01],
#        [-1.17933389e+00, -1.39776567e+00, -1.57640046e+00,
#         -1.55530604e+00],
#        [-4.83296918e-01,  4.97168021e-01, -1.55816006e+00,
#          8.89716558e-01],
#        [ 1.75694944e+00,  2.66214798e-01, -6.94578651e-01,
#         -1.01196769e+00],
#        [ 3.16016298e-01,  4.07306660e-01, -4.71354979e-01,
#         -3.32794743e-01],
#        [-1.43110870e+00, -9.14624268e-01,  2.32082200e-01,
#          1.43305491e+00],
#        [ 9.91464832e-01,  1.30087512e+00,  1.07853548e+00,
#         -6.04463921e-01],
#        [ 1.07404206e+00, -2.81275515e-01, -8.60833687e-01,
#         -1.41947145e+00],
#        [-1.51453870e+00, -7.40421299e-01,  1.60597782e-01,
#         -3.32794743e-01],
#        [ 2.66698923e-01, -1.53690372e+00,  1.55119975e+00,
#          1.02555115e+00],
#        [ 1.92372553e-01, -1.08532932e+00,  8.23435296e-01,
#          1.16138574e+00],
#        [-6.33104533e-01, -1.40716878e+00,  1.26212019e+00,
#          1.02555115e+00],
#        [ 1.44894108e-02, -9.00535488e-01,  3.01705414e-01,
#         -1.28363687e+00],
#        [-1.05601642e+00,  1.32477038e+00,  3.53978904e-01,
#          1.43305491e+00],
#        [-1.42696773e+00, -1.69081296e-03,  4.36799621e-01,
#          7.47090239e-02],
#        [ 1.53684414e+00, -8.99856977e-01,  1.87638075e-01,
#         -1.14780228e+00],
#        [ 8.13002877e-01, -1.45166011e+00, -1.13963903e+00,
#          7.53881969e-01],
#        [ 2.53108566e-01,  1.08321108e+00,  8.04253845e-01,
#         -3.32794743e-01],
#        [-4.01704767e-02, -9.47056755e-01, -7.89733571e-01,
#          3.46378202e-01],
#        [-5.28908200e-01,  3.28628303e-01, -2.43456565e-01,
#          6.18047380e-01],
#        [-1.33183232e+00, -1.57268304e+00, -4.73699508e-01,
#          1.56888950e+00],
#        [ 5.25992725e-01, -1.32967165e+00, -5.45749079e-01,
#          7.53881969e-01],
#        [-1.05609808e+00, -8.75665748e-01, -1.64780382e+00,
#         -6.04463921e-01],
#        [ 1.68498940e+00,  1.44291342e+00, -1.02422113e+00,
#         -1.01196769e+00],
#        [ 6.58789001e-01, -1.58568024e+00,  1.43287762e+00,
#          3.46378202e-01],
#        [ 1.23406689e+00,  1.39874904e+00,  5.06592243e-01,
#          6.18047380e-01],
#        [ 4.21434163e-01, -1.68574439e+00,  1.31130229e+00,
#         -6.04463921e-01],
#        [ 1.02696358e+00,  6.00638001e-01,  9.97069493e-01,
#         -1.41947145e+00],
#        [-1.36904754e+00,  1.22372914e+00, -1.36362461e+00,
#         -1.55530604e+00],
#        [-1.36399206e+00, -1.30830540e+00,  2.55017387e-01,
#          4.82212791e-01],
#        [-1.56553349e+00,  2.80769133e-03,  1.22759446e+00,
#          4.82212791e-01],
#        [-5.54194485e-01,  9.77478982e-01, -5.87966126e-01,
#         -1.01196769e+00],
#        [ 1.22152290e+00,  4.08738198e-01, -1.20910118e+00,
#         -1.14780228e+00],
#        [-9.08218716e-01,  1.02542279e+00,  1.58267478e+00,
#          1.29722032e+00],
#        [-3.76414340e-01,  8.19690825e-02,  5.86901897e-02,
#         -1.41947145e+00],
#        [-1.17105958e+00,  1.50822241e+00,  1.47356815e+00,
#          8.89716558e-01],
#        [ 8.30513773e-01,  1.29017069e+00, -1.55344776e+00,
#         -1.55530604e+00],
#        [ 1.56749570e-01,  1.16821043e+00, -3.61058093e-01,
#          4.82212791e-01],
#        [-9.58390638e-01, -7.77542329e-01,  1.18045902e+00,
#         -1.01196769e+00],
#        [-4.82799209e-01,  7.25250504e-01, -1.35291720e+00,
#         -3.32794743e-01]])

# %%
model =LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# 5. 模型评估
y_pred=model.predict(x_test)
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.9864431628163263

# %%
#均方误差
mse = mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 5.72288300490447
