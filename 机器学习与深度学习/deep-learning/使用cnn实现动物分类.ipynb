# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models,layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Input,Dropout
import matplotlib.pyplot as plt

# %%
datagen = ImageDataGenerator(
    validation_split=0.2,
    rescale=1./255
)

# %%
train_generator =  datagen.flow_from_directory(
    './data',
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
)
validation_generator = datagen.flow_from_directory(
    './data',
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)
# Out:
# Found 2160 images belonging to 9 classes.
# Found 2700 images belonging to 9 classes.

# %%
train_generator.class_indices
# Out:
# {'兔子': 0, '牛': 1, '狗狗': 2, '猪': 3, '猫猫': 4, '羊': 5, '马': 6, '鲨鱼': 7, '鸡': 8}

# %%
model = Sequential([
    Input(shape=(224,224,3)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(256,(3,3),activation='relu'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(256,activation='relu'),
    Dense(512,activation='relu'),
    Dense(9,activation='softmax')
])

# %%
#编译模型
model.compile(
    optimizer='adam', #优化器 梯度下降算法
    loss='categorical_crossentropy',
    metrics=['accuracy'] #评估的指标
)

# %%
#训练模型
import time
start = time.time()
history = model.fit(train_generator,validation_data=validation_generator,epochs=10)
end = time.time()
print('模型训练时间为:',end-start)
# Out:
# Epoch 1/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 579s 8s/step - accuracy: 0.1958 - loss: 2.1289 - val_accuracy: 0.2437 - val_loss: 1.9461
# Epoch 2/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 543s 8s/step - accuracy: 0.2829 - loss: 1.9106 - val_accuracy: 0.3307 - val_loss: 1.7888
# Epoch 3/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 538s 8s/step - accuracy: 0.3347 - loss: 1.7549 - val_accuracy: 0.3837 - val_loss: 1.6971
# Epoch 4/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 530s 8s/step - accuracy: 0.4458 - loss: 1.5275 - val_accuracy: 0.5144 - val_loss: 1.3994
# Epoch 5/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 527s 8s/step - accuracy: 0.6042 - loss: 1.1258 - val_accuracy: 0.7004 - val_loss: 0.9454
# Epoch 6/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 525s 8s/step - accuracy: 0.8051 - loss: 0.5858 - val_accuracy: 0.8241 - val_loss: 0.7628
# Epoch 7/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 535s 8s/step - accuracy: 0.9148 - loss: 0.2587 - val_accuracy: 0.8548 - val_loss: 1.0467
# Epoch 8/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 553s 8s/step - accuracy: 0.9630 - loss: 0.1278 - val_accuracy: 0.8537 - val_loss: 1.1599
# Epoch 9/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 549s 8s/step - accuracy: 0.9625 - loss: 0.1350 - val_accuracy: 0.8522 - val_loss: 1.1165
# Epoch 10/10
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 565s 8s/step - accuracy: 0.9801 - loss: 0.0731 - val_accuracy: 0.8685 - val_loss: 1.0771
# 模型训练时间为: 5444.987077951431
