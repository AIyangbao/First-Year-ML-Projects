# %% [markdown]
# 绘制图表

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.plot(x,y,'+')

# %%
#字符 类型 字符 类型 '-' 实线 '--' 虚线 '-.' 虚点线 ':' 点线 '.' 点 ',' 像素点 'o' 圆点 'v' 下三角点 '^' 上三角点 '<' 左三角点 '>' 右三角点 '1' 下三叉点 '2' 上三叉点 '3' 左三叉点 '4' 右三叉点 's' 正方点 'p' 五角点 '*' 星形点 'h' 六边形点1 'H' 六边形点2 '+' 加号点 'x' 乘号点 'D' 实心菱形点 'd' 瘦菱形点 '_' 横线点

# %%
#对图表进行添加颜色
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.plot(x,y,'g')

# %%
#字符 颜色 'b' 蓝色，blue 'g' 绿色，green 'r' 红色，red 'c' 青色，cyan 'm' 品红，magenta 'y' 黄色，yellow 'k' 黑色，black 'w' 白色，white

# %%
#添加轴的标签
#对图表进行添加颜色
#设置中文编码和负号的正常显示
plt.rcParams['font.sans-serif']= 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus']=False
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.plot(x,y,'r')
#添加x轴的标签
plt.xlabel("x轴")
plt.ylabel("y轴")
#绘制标题
plt.title("图形")
# Out:
# Text(0.5, 1.0, '图形')

# %% [markdown]
# 绘制常见图表

# %%
#条形图
import numpy as np
arr_random=np.random.randn(100)
plt.hist(arr_random,bins=8,color='r',alpha=0.7)
plt.show()

# %%
#票房单位亿元
movies={
    "流浪地球":40.78,
    "飞驰人生":15.77,
    "疯狂的外星人":20.83,
    "新喜剧之王":6.10,
    "廉政风云":1.10,
    "神探蒲松龄":1.49,
    "小猪佩奇过大年":1.22,
    "熊出没·原始时代":6.71
}

# %%
import numpy as np
from matplotlib import font_manager
import pandas as pd
#加载字体
font = font_manager.FontProperties(fname=r"C:\Windows\Fonts\msyh.ttc")
#票房单位亿元
movies={
    "流浪地球":40.78,
    "飞驰人生":15.77,
    "疯狂的外星人":20.83,
    "新喜剧之王":6.10,
    "廉政风云":1.10,
    "神探蒲松龄":1.49,
    "小猪佩奇过大年":1.22,
    "熊出没·原始时代":6.71
}

#设置画布大小
plt.figure(figsize=(12,6))
plt.bar(np.arange(len(movies)),list(movies.values()))
#rotation 角度倾斜
plt.xticks(np.arange(len(movies)),list(movies.keys()),rotation=45)
plt.grid()

# %%
#设置画布大小
plt.figure(figsize=(12,6))
plt.barh(np.arange(len(movies)),list(movies.values()))
#rotation 角度倾斜
plt.yticks(np.arange(len(movies)),list(movies.keys()))
plt.grid()

# %%
movies={
    "流浪地球":[2.01,4.59,7.99,11.83,16],
    "风驰人生":[3.19,5.08,6.73,8.10,9.35],
    "疯狂的外星人":[4.07,6.92,9.30,11.29,13.03],
    "新喜剧之王":[2.72,3.79,4.45,4.83,5.11],
    "廉政风云":[0.56,0.74,0.83,0.88,0.92],
    "神探蒲松龄":[0.66,0.95,1.10,1.17,1.23],
    "小猪佩奇过大年":[0.58,0.81,0.94,1.01,1.07],
    "熊出没·原始时代":[1.13,1.96,2.73,3.42,4.05]
}

# %%
plt.figure(figsize=(20,8))
width=0.75
bin_width=width/5
movie_pd=pd.DataFrame(movies)
ind=np.arange(0,len(movies))
first_day=movie_pd.iloc[0]
plt.bar(ind-bin_width*2,first_day,width=bin_width,label="第一天")
second_day=movie_pd.iloc[1]
plt.bar(ind-bin_width,second_day,width=bin_width,label="第二天")
third_day=movie_pd.iloc[2]
plt.bar(ind,third_day,width=bin_width,label="第三天")
four_day=movie_pd.iloc[3]
plt.bar(ind+bin_width,four_day,width=bin_width,label="第四天")
five_day=movie_pd.iloc[4]
plt.bar(ind+bin_width*2,five_day,width=bin_width,label="第五天")
plt.legend()
plt.ylabel("单位:亿")
plt.title("春节前5天电影票房")
#设置y轴的数据
plt.xticks(ind,movie_pd.columns)
plt.xlim
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,8))
width=0.75
bin_width=width/5
movie_pd=pd.DataFrame(movies)
ind=np.arange(0,len(movies))
for index in movie_pd.index:
    day_tickets = movie_pd.iloc[index]
    xs = ind-(bin_width*(2-index))
    plt.bar(xs,day_tickets,width=bin_width,label="第%d天"%(index+1))
    for ticket,x in zip(day_tickets,xs):
        plt.annotate(ticket,xy=(x,ticket),xytext=(x-0.1,ticket+0.1))
plt.legend()
plt.ylabel("单位:亿")
plt.title("春节前5天电影票房")
#设置y轴的数据
plt.xticks(ind,movie_pd.columns)
plt.xlim
plt.grid(True)

# %%
m=(20,35,30,35,27)
w=(25,32,34,20,35)
g=('G1','G2','G3','G4','G5')
xs=np.arange(len(m))
plt.bar(xs,m)
plt.bar(xs,w,bottom=m)
#设置x轴的数据
plt.xticks(xs,g)
plt.show()

# %%
#电影时长数据
durations=[131,98,125,131,124,139,131,117,128,108,135,138,131,102,107,114, 119, 128, 121, 142, 127, 130, 124, 101, 110, 116, 117, 110, 128, 128, 115, 99]
plt.figure(figsize=(10,6))
plt.hist(durations,bins=20,color='b')
plt.title("电影时长发布")
plt.show()

# %%
#散点图
x=np.arange(51)
y=np.random.rand(51)*10
plt.scatter(x,y)
plt.show()

# %%
#绘制pie图
labels=['娱乐','育儿','饮食','房贷','交通']
sizes=[2,5,12,70,2,]
e=(0,0,0.1,0,0)
plt.pie(sizes,explode=e,labels=labels,autopct="%1.2f%%",shadow=False,startangle=150)
plt.title("绘制一个pie图")
plt.show()

# %%
#a绘制箱线图
data= np.random.rand(100)*100
#添加异常值
data=np.append(data,np.array([-100,100]))
plt.boxplot(data,meanline=True,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c3d46a7250>,
#   <matplotlib.lines.Line2D at 0x1c3d46a41d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c3d46a7650>,
#   <matplotlib.lines.Line2D at 0x1c3d46a6d10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c3d449d410>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c3d46a5290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c3d44814d0>],
#  'means': [<matplotlib.lines.Line2D at 0x1c3d46a4c50>]}

# %%
#雷达图
properties=['输出','KDA','发育','团战','生存','补刀']
values=[40,91,44,90,95,40]
theta = np.linspace(0,np.pi*2,6,endpoint=False)#不包含终点
plt.figure(figsize=(8,8))
plt.polar(theta,values)
plt.xticks(theta,properties)
plt.fill(theta,values)
plt.title("游戏",size=14)
plt.show()
